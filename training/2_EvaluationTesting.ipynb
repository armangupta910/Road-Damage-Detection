# %%
from ultralytics import YOLO

# %%
# India_Filtered
_data = "/home/armangupta/project/RoadDamageDetection/training/dataset/rddIndiaFiltered/rdd_India.yaml"

# %%
weight_path = "/home/armangupta/project/RoadDamageDetection/models/YOLOv8_Small_RDD.pt"

model = YOLO(weight_path)
metrics = model.val(data=_data)
